# %% [markdown]
# # Assignment **2**

# %%
import pandas as pd
people = ['kiran','arun','vijay','varun']
age = [25,30,35,40]
height = [145,151,165,173]
weight= [45,55,65,75]


# Create the pandas DataFrame
df = pd.DataFrame({'person':people,'age':age,'height':height,'weight':weight})



df
# Out:
#   person  age  height  weight
# 0  kiran   25     145      45
# 1   arun   30     151      55
# 2  vijay   35     165      65
# 3  varun   40     173      75

# %%
import matplotlib.pyplot as plt

x1 = df['age']
y1 = df['weight']

plt.scatter(x1,y1,c='red')
plt.xlabel('age')
plt.ylabel('weight')
plt.grid()

# %%
x2 = df['weight']
y2 = df['height']

plt.scatter(x2,y2,c='blue')
plt.xlabel('weight')
plt.ylabel('height')
plt.grid()

# %%
x3 = df['age']
y3 = df['height']

plt.scatter(x2,y2,c='y')
plt.xlabel('age')
plt.ylabel('height')
plt.grid()

# %%
x4 = df['weight']
y4 = df['height']

plt.bar(x4,y4)
plt.xlabel('weight')
plt.ylabel('height')
plt.show()

# %%
x5 = df['age']
y5 = df['height']

plt.bar(x5,y5)
plt.xlabel('age')
plt.ylabel('height')
plt.grid()

# %%
x6 = df['age']
y6 = df['weight']

plt.bar(x2,y2)
plt.xlabel('age')
plt.ylabel('weight')
plt.grid()

# %%
plt.hist(df['age'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('age')
plt.ylabel('values')
plt.title('age histogram')
plt.show()

# %%
plt.hist(df['weight'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('weight')
plt.ylabel('values')
plt.title('weight histogram')
plt.show()

# %%
plt.hist(df['height'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('height')
plt.ylabel('values')
plt.title('height histogram')
plt.show()
